# %% [markdown]
# # Ziad Elsayed Ebrahim
# # Tasneem Samir Mohamed
# # Marwan Wael El-Wageeh
# # Mohamed Yasser Mohamed Hamdy

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'notebook_connected'
plt.style.use('seaborn-v0_8')
colors_palette = plt.get_cmap('Set3').colors
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=colors_palette)
# %matplotlib inline

# %%
df = pd.read_csv('social_media_engagement1.csv')

df['post_time'] = pd.to_datetime(df['post_time'], errors='coerce')
df['likes'] = pd.to_numeric(df['likes'], errors='coerce')
df['comments'] = pd.to_numeric(df['comments'], errors='coerce')
df['shares'] = pd.to_numeric(df['shares'], errors='coerce')
df['sentiment_score'] = df['sentiment_score'].astype(str).str.lower()
df['post_hour'] = df['post_time'].dt.hour

df['engagment'] = df['likes'] + df['comments'] + df['shares']
df['total_engagement'] = df['engagment']

# %%
df.head()
# Out:
#    post_id   platform post_type           post_time  likes  comments  shares  \
# 0        1   Facebook     image 2023-08-17 14:45:00   2121       474     628
# 1        2   Facebook  carousel 2023-05-14 00:45:00   3660       432     694
# 2        3  Instagram      poll 2023-02-21 16:15:00   4955       408     688
# 3        4    Twitter     image 2023-11-16 00:45:00   1183        90     187
# 4        5    Twitter     video 2023-05-23 00:30:00   3499       247     286
#
#    post_day sentiment_score  post_hour  engagment  total_engagement
# 0  Thursday        positive         14       3223              3223
# 1    Sunday         neutral          0       4786              4786
# 2   Tuesday        negative         16       6051              6051
# 3  Thursday        negative          0       1460              1460
# 4   Tuesday        positive          0       4032              4032

# %%
df.shape
# Out:
# (100, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   post_id           100 non-null    int64
#  1   platform          100 non-null    object
#  2   post_type         100 non-null    object
#  3   post_time         100 non-null    datetime64[ns]
#  4   likes             100 non-null    int64
#  5   comments          100 non-null    int64
#  6   shares            100 non-null    int64
#  7   post_day          100 non-null    object
#  8   sentiment_score   100 non-null    object
#  9   post_hour         100 non-null    int32
#  10  engagment         100 non-null    int64
#  11  total_engagement  100 non-null    int64
# dtypes: datetime64[ns](1), int32(1), int64(6), object(4)
# memory usage: 9.1+ KB

# %%
df.describe(include='all')
# Out:
#            post_id   platform post_type            post_time        likes  \
# count   100.000000        100       100                  100   100.000000
# unique         NaN          3         5                  NaN          NaN
# top            NaN  Instagram  carousel                  NaN          NaN
# freq           NaN         36        26                  NaN          NaN
# mean     50.500000        NaN       NaN  2023-06-26 12:04:57  2381.810000
# min       1.000000        NaN       NaN  2023-01-01 06:00:00    15.000000
# 25%      25.750000        NaN       NaN  2023-04-09 16:48:45   895.750000
# 50%      50.500000        NaN       NaN  2023-06-13 18:22:30  2220.000000
# 75%      75.250000        NaN       NaN  2023-10-02 15:03:45  3593.250000
# max     100.000000        NaN       NaN  2023-12-31 22:30:00  5000.000000
# std      29.011492        NaN       NaN                  NaN  1632.573284
#
#          comments      shares   post_day sentiment_score   post_hour  \
# count   100.00000  100.000000        100             100  100.000000
# unique        NaN         NaN          7               3         NaN
# top           NaN         NaN  Wednesday        positive         NaN
# freq          NaN         NaN         18              46         NaN
# mean    202.66000  415.650000        NaN             NaN   11.020000
# min      10.00000   16.000000        NaN             NaN    0.000000
# 25%      89.75000  183.000000        NaN             NaN    5.000000
# 50%     171.00000  356.500000        NaN             NaN   11.000000
# 75%     299.00000  689.500000        NaN             NaN   17.000000
# max     500.00000  993.000000        NaN             NaN   23.000000
# std     138.84067  283.877601        NaN             NaN    7.072468
#
#           engagment  total_engagement
# count    100.000000        100.000000
# unique          NaN               NaN
# top             NaN               NaN
# freq            NaN               NaN
# mean    3000.120000       3000.120000
# min      435.000000        435.000000
# 25%     1497.250000       1497.250000
# 50%     2612.500000       2612.500000
# 75%     4408.250000       4408.250000
# max     6410.000000       6410.000000
# std     1773.559574       1773.559574

# %%
df.isnull().sum()
# Out:
# post_id             0
# platform            0
# post_type           0
# post_time           0
# likes               0
# comments            0
# shares              0
# post_day            0
# sentiment_score     0
# post_hour           0
# engagment           0
# total_engagement    0
# dtype: int64

# %%
for col in df.columns[1:]:
    plt.figure(figsize=(8, 4))
    if pd.api.types.is_numeric_dtype(df[col]):
        sns.histplot(df[col].dropna(), kde=True)
        plt.title(f'Distribution of {col}')
    elif pd.api.types.is_categorical_dtype(df[col]) or df[col].dtype == object:
        df[col].value_counts().plot(kind='bar')
        plt.title(f'Value Counts of {col}')
    else:
        plt.text(0.5, 0.5, f'Cannot plot column: {col}', ha='center')
    plt.xlabel(col)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\tasne\AppData\Local\Temp\ipykernel_31600\3421912604.py:6: DeprecationWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
# C:\Users\tasne\AppData\Local\Temp\ipykernel_31600\3421912604.py:6: DeprecationWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
# C:\Users\tasne\AppData\Local\Temp\ipykernel_31600\3421912604.py:6: DeprecationWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
# C:\Users\tasne\AppData\Local\Temp\ipykernel_31600\3421912604.py:6: DeprecationWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
# C:\Users\tasne\AppData\Local\Temp\ipykernel_31600\3421912604.py:6: DeprecationWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead

# %%
grouped = df.groupby(['platform', 'post_type'])['engagment'].agg([np.mean, min, max]).sort_values(by='mean', ascending=False)
grouped.head(10)
# Out:
# C:\Users\tasne\AppData\Local\Temp\ipykernel_31600\294127826.py:1: FutureWarning:
#
# The provided callable <function mean at 0x0000023F58D01260> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#
# C:\Users\tasne\AppData\Local\Temp\ipykernel_31600\294127826.py:1: FutureWarning:
#
# The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#
# C:\Users\tasne\AppData\Local\Temp\ipykernel_31600\294127826.py:1: FutureWarning:
#
# The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#                             mean   min   max
# platform  post_type
# Facebook  poll       4985.333333  2971  6222
# Instagram video      4862.285714  1723  6198
#           poll       4325.166667  3385  6051
#           image      4160.000000  2362  5482
# Facebook  video      4092.444444   787  6410
# Instagram carousel   3316.777778   653  6051
# Facebook  carousel   3158.000000   498  5549
#           text       3117.166667  1185  4145
# Twitter   carousel   2481.142857  1122  3769
# Instagram text       2330.000000   539  3486

# %%
sns.boxplot(x=df['engagment'])
plt.title("Engagement Distribution")
plt.tight_layout()
plt.show()

sns.boxplot(x='post_day', y='engagment', data=df)
plt.title("Engagement by Day of Week")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

sns.barplot(data=df, x='post_type', y='engagment')
plt.title("Engagement by Post Type")
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x='platform', y='engagment', data=df, estimator=sum)
plt.title("Total Engagement by Platform")
plt.tight_layout()
plt.show()

# %%
pivot = pd.pivot_table(df, values='engagment', index='platform', columns='post_type', aggfunc='mean')
plt.figure(figsize=(10, 6))
sns.heatmap(pivot, annot=True, cmap="YlGnBu", fmt=".0f")
plt.title("Average Engagement by Platform and Post Type")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='platform', hue='sentiment_score', data=df)
plt.title("Sentiment Distribution by Platform")
plt.tight_layout()
plt.show()

sns.countplot(data=df, x='sentiment_score', order=df['sentiment_score'].value_counts().index)
plt.title("Sentiment Distribution")
plt.show()

# %%
fig1 = px.bar(
    df.groupby('platform')['total_engagement'].sum().reset_index().sort_values(by='total_engagement', ascending=False),
    x='platform',
    y='total_engagement',
    title='Total Engagement by Platform',
    text_auto=True,
    color='platform'
)
fig1.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="b80105d6-6d64-4244-9671-9127f9c19c6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b80105d6-6d64-4244-9671-9127f9c19c6c")) {                    Plotly.newPlot(                        "b80105d6-6d64-4244-9671-9127f9c19c6c",                        [{"hovertemplate":"platform=%{x}\u003cbr\u003etotal_engagement=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Instagram","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Instagram","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Instagram"],"xaxis":"x","y":{"dtype":"i4","bdata":"ZBACAA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"platform=%{x}\u003cbr\u003etotal_engagement=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Facebook","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Facebook","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Facebook"],"xaxis":"x","y":{"dtype":"i4","bdata":"4asBAA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"platform=%{x}\u003cbr\u003etotal_engagement=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Twitter","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Twitter","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Twitter"],"xaxis":"x","y":{"dtype":"i4","bdata":"p9cAAA=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoord ...

# %%
fig2 = px.histogram(df, x='likes', nbins=30, title='Distribution of Likes')
fig2.show()

fig3 = px.histogram(df, x='shares', nbins=30, title='Distribution of Shares')
fig3.show()

fig4 = px.histogram(df, x='comments', nbins=30, title='Distribution of Comments')
fig4.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="490de879-1257-435b-a6bd-ae45b2f0ef37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("490de879-1257-435b-a6bd-ae45b2f0ef37")) {                    Plotly.newPlot(                        "490de879-1257-435b-a6bd-ae45b2f0ef37",                        [{"bingroup":"x","hovertemplate":"likes=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":30,"orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":""},"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"hi ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="a6431e38-06d7-4273-adcb-b2d10b5ff993" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a6431e38-06d7-4273-adcb-b2d10b5ff993")) {                    Plotly.newPlot(                        "a6431e38-06d7-4273-adcb-b2d10b5ff993",                        [{"bingroup":"x","hovertemplate":"shares=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":30,"orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":"dAK2ArACuwAeAdMAigPYAN0AtgE0AFkAdwF7AAYBEgDgAlIBtwBPADcAtwFcAY8B4AEDAokAhAHbAuMC0gO3APAAHABUAysAUwC9AdQDTQPNAdoCVQCxAHYAqwHhAxAAKgF\u002fAPsARwFgADkD8AHmAPIB2ALCALwD+QJRA38A1AJGAT4BpQClAhwBxQN2ApAC+QLoApQBcgBgAG0BEQM4AZ0B9QIYA6EBMAE+AMYBQwBTAfMAzgFYAd4CIgEFAo8DygEmAMwAGQA="},"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}} ...
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="ab3ea990-5951-491b-abbc-99df603f9d4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ab3ea990-5951-491b-abbc-99df603f9d4b")) {                    Plotly.newPlot(                        "ab3ea990-5951-491b-abbc-99df603f9d4b",                        [{"bingroup":"x","hovertemplate":"comments=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":30,"orientation":"v","showlegend":false,"x":{"dtype":"i2","bdata":""},"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}], ...

# %%
avg_comments = df.groupby("platform")["comments"].mean().reset_index()

fig = px.pie(
    avg_comments,
    values='comments',
    names='platform',
    title='Average Comments per Platform',
    width=400,
    height=400
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="283c69ab-e599-41ae-b7d3-1d14233dcf27" class="plotly-graph-div" style="height:400px; width:400px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("283c69ab-e599-41ae-b7d3-1d14233dcf27")) {                    Plotly.newPlot(                        "283c69ab-e599-41ae-b7d3-1d14233dcf27",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"platform=%{label}\u003cbr\u003ecomments=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Facebook","Instagram","Twitter"],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"f8","bdata":"AAAAAAAdb0DkOI7jOA5tQAAAAAAAul5A"},"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ti ...

# %%
df_sorted = df.sort_values(by='post_time')
plt.plot(df_sorted['post_time'], df_sorted['likes'])
plt.title("Likes Over Time")
plt.xlabel("Date")
plt.ylabel("Likes")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
engagement = df.groupby("post_type")[["likes", "comments", "shares"]].mean().reset_index()
engagement = pd.melt(engagement, id_vars="post_type", var_name="metric", value_name="avg_value")

plt.figure(figsize=(10, 6))
sns.barplot(data=engagement, x="post_type", y="avg_value", hue="metric")
plt.title("Average Engagement by Post Type")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.groupby('post_day')[['likes', 'comments', 'shares']].mean().plot(kind='bar')
plt.title('Average Engagement per Day')
plt.ylabel('Average Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sentiment = df.groupby(["platform", "sentiment_score"]).size().reset_index(name='count')
fig = px.bar(sentiment, x="platform", y="count", color="sentiment_score",
             title="Sentiment Distribution by Platform", barmode="stack")
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="304653b1-5ed2-4c0d-96d3-79fe7587e350" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("304653b1-5ed2-4c0d-96d3-79fe7587e350")) {                    Plotly.newPlot(                        "304653b1-5ed2-4c0d-96d3-79fe7587e350",                        [{"hovertemplate":"sentiment_score=negative\u003cbr\u003eplatform=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"negative","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"negative","orientation":"v","showlegend":true,"textposition":"auto","x":["Facebook","Instagram","Twitter"],"xaxis":"x","y":{"dtype":"i1","bdata":"Cw4C"},"yaxis":"y","type":"bar"},{"hovertemplate":"sentiment_score=neutral\u003cbr\u003eplatform=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"neutral","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"neutral","orientation":"v","showlegend":true,"textposition":"auto","x":["Facebook","Instagram","Twitter"],"xaxis":"x","y":{"dtype":"i1","bdata":"CQgK"},"yaxis":"y","type":"bar"},{"hovertemplate":"sentiment_score=positive\u003cbr\u003eplatform=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"positive","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"positive","orientation":"v","showlegend":true,"textposition":"auto","x":["Facebook","Instagram","Twitter"],"xaxis":"x","y":{"dtype":"i1","bdata":"DA4U"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode ...

# %% [markdown]
# # dataset :
#
# post_types(image,video,text,carousel,poll)
#
# Engagement metrics(likes, shares, comments)
#
# post_time
#
# sentiment_score
#
# for three differnet social media platforms(Facebook,Instagram,Twitter).
#
#
# # key findings:
# ### Platforms:
#
#       -Instagram posts tend to have higher engagement compared to twitter and facebook.
#
#       -Twitter receives the most positive sentiment posts.
#
#
# ###  Post Type:
#
#       -Polls on Facebook get the highest average engagement
#
#       -videos on instagram are also highly engagying.
#
#       -text posts perform the worst across all platforms.
#
#
# ### Posts time:
#
#       -Sunday and Friday Posts has the highest average engageament (This pattern likely reflects audience availability in weekends)
#
#       -Early morning (1 AM) and evening (9 PM) are the most engaging posting times.
#
#       -mid-afternoon (3 PM) consistently shows lowest engagement.
#
#
# ###  Sentiment Analysis:
#
#       -Twitter had the highest number of posts with positive sentiment.
#
#       -Sentiment patterns differ by platform but weren’t directly correlated to engagement.
#
#
# ### conclusion :
#
#       to maximize engagement across social media:
#
#       -prioritize Instagram for visual content.
#
#       -use videos and polls more than text.
#
#       -Schedule posts for late evening or early morning on weekends.
#
#       -don't rely only on positive sentiment; content type and timing are stronger predictors of engagement
